# %% [markdown]
# # Forecasting
#
#
# In this lesson, we will practice forecasting using the following methods:
#
# - Last observed value
# - Simple average
# - Moving average
# - Holt's Linear Trend
# - Previous cycle
#
# ______________________________
#
#
# We will walk through steps from previous lessons to get the data ready to model
#
# - Acquire data: prepare.acquire_store_data()
# - Prepare data: prepare.prep_store_data()
# - Split data: prepare.split_store_data()
#
# Then we will forecast and evaluate using each method.

# %%
# for presentation purposes
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd

# visualize 
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# wrangle
import acquire
import prepare

# working with dates
from datetime import datetime

# to evaluated performance using rmse
from sklearn.metrics import mean_squared_error
from math import sqrt 

# for tsa 
import statsmodels.api as sm

# holt's linear trend model. 
from statsmodels.tsa.api import Holt

# %% [markdown]
# ## Wrangle

# %%
df = acquire.get_store_data()
df = prepare.prep_store_data(df)
df.head()
# Out:
# Data is cached. Reading from .csv files
# Items data acquired...
# Stores data acquired...
# Sales data acquired...
# Acquisition complete
#                            quantity  sale_id  item_brand  item_id  \
# sale_date
# 2013-01-01 00:00:00+00:00      13.0        1    Riceland        1
# 2013-01-01 00:00:00+00:00      26.0   211817     Mueller       12
# 2013-01-01 00:00:00+00:00      27.0   832657  Mama Marys       46
# 2013-01-01 00:00:00+00:00      54.0   213643     Mueller       12
# 2013-01-01 00:00:00+00:00      35.0   215469     Mueller       12
#
#                                                                    item_name  \
# sale_date
# 2013-01-01 00:00:00+00:00                     Riceland American Jazmine Rice
# 2013-01-01 00:00:00+00:00  Mueller Sport Care Basic Support Level Medium ...
# 2013-01-01 00:00:00+00:00                                        Pizza Sauce
# 2013-01-01 00:00:00+00:00  Mueller Sport Care Basic Support Level Medium ...
# 2013-01-01 00:00:00+00:00  Mueller Sport Care Basic Support Level Medium ...
#
#                            item_price           store_address   store_city  \
# sale_date
# 2013-01-01 00:00:00+00:00        0.84  12125 Alamo Ranch Pkwy  San Antonio
# 2013-01-01 00:00:00+00:00        8.40  12018 Perrin Beitel Rd  San Antonio
# 2013-01-01 00:00:00+00:00        4.65  12018 Perrin Beitel Rd  San Antonio
# 2013-01-01 00:00:00+00:00        8.40     15000 San Pedro Ave  San Antonio
# 2013-01-01 00:00:00+00:00        8.40      735 SW Military Dr  San Antonio
#
#                            store_id store_state  store_zipcode  month  year  \
# sale_date
# 2013-01-01 00:00:00+00:00         1          TX          78253      1  2013
# 2013-01-01 00:00:00+00:00         7          TX          78217      1  2013
# 2013-01-01 00:00:00+00:00         7          TX          78217      1  2013
# 2013-01-01 00:00:00+00:00         8          TX          78232      1  2013
# 2013-01-01 00:00:00+00:00         9          TX          78221      1  2013
#
#                            sales_total
# sale_date
# 2013-01-01 00:00:00+00:00        10.92
# 2013-01-01 00:00:00+00:00       218.40
# 2013-01-01 00:00:00+00:00       125.55
# 2013-01-01 00:00:00+00:00       453.60
# 2013-01-01 00:00:00+00:00       294.00

# %% [markdown]
# We will resample to daily, but essentially what we are doing is grouping by the day and aggregating using sum. The original granularity is daily, but there are multiple records of the same days across multiple stores.

# %%
df_resampled = df.resample('d')[['quantity','sales_total']].sum()
df_resampled.head()
# Out:
#                            quantity  sales_total
# sale_date
# 2013-01-01 00:00:00+00:00   13696.0     73844.01
# 2013-01-02 00:00:00+00:00   13678.0     73570.58
# 2013-01-03 00:00:00+00:00   14488.0     78169.48
# 2013-01-04 00:00:00+00:00   15677.0     84467.73
# 2013-01-05 00:00:00+00:00   16237.0     87621.85

# %% [markdown]
# ## Split
#
# 1. We will use the training proportion method to split.
# 2. Identify the total length of the dataframe and multiply by `train_prop` to get the number of rows that equates to the first x% of the dataframe, which equates to the first x% of the time covered in the data.   (`x = train_prop * 100`)
# 3. Select row indices from 0 up to the index representing x-percentile for train, and from the index representing x-percentile through the end of the dataframe for test. In both of these, we will reset the index in order to return dataframes sorted by datetime.
# 4. Return train and test dataframes.

# %%
df_resampled.shape
# Out:
# (1826, 2)

# %%
# set train size to be 50% of total 
train_size = int(round(df_resampled.shape[0] * 0.5))
train_size
# Out:
# 913

# %%
# set validate size to be 30% of total 
validate_size = int(round(df_resampled.shape[0] * 0.3))
validate_size
# Out:
# 548

# %%
# set test size to be number of rows remaining. 
test_size = int(round(df_resampled.shape[0] * 0.2))
test_size
# Out:
# 365

# %%
len(df_resampled) == train_size + validate_size + test_size
# Out:
# True

# %%
# validate will go from 912 to 912+547
validate_end_index = train_size + validate_size
validate_end_index
# Out:
# 1461

# %% [markdown]
# Use those values to split our dataframe

# %%
# train will go from 0 to 911
train = df_resampled[:train_size]

# %%
# validate will go from 912 to 1458
validate = df_resampled[train_size:validate_end_index]

# %%
train.tail()
# Out:
#                            quantity  sales_total
# sale_date
# 2015-06-28 00:00:00+00:00   37410.0    201002.82
# 2015-06-29 00:00:00+00:00   25074.0    134932.08
# 2015-06-30 00:00:00+00:00   29345.0    158904.06
# 2015-07-01 00:00:00+00:00   30703.0    164573.20
# 2015-07-02 00:00:00+00:00   33134.0    178036.64

# %%
validate.tail()
# Out:
#                            quantity  sales_total
# sale_date
# 2016-12-27 00:00:00+00:00   19341.0    103657.89
# 2016-12-28 00:00:00+00:00   19560.0    105313.94
# 2016-12-29 00:00:00+00:00   21111.0    113221.85
# 2016-12-30 00:00:00+00:00   22296.0    120033.64
# 2016-12-31 00:00:00+00:00   23792.0    128009.31

# %%
# test will include 1459 to the end
test = df_resampled[validate_end_index:]

# %%
test.head()
# Out:
#                            quantity  sales_total
# sale_date
# 2017-01-01 00:00:00+00:00   23709.0    127262.71
# 2017-01-02 00:00:00+00:00   15772.0     85329.98
# 2017-01-03 00:00:00+00:00   18650.0    100389.65
# 2017-01-04 00:00:00+00:00   18510.0     99454.59
# 2017-01-05 00:00:00+00:00   19895.0    107613.80

# %%
train.shape[0], validate.shape[0], test.shape[0]
# Out:
# (913, 548, 365)

# %% [markdown]
# **Verify Splits**
#
# Does the length of each df equate to the length of the original df?

# %%
# is len of train + validate + test == lenght of entire dataframe. 
len(train) + len(validate) + len(test) == len(df_resampled)
# Out:
# True

# %% [markdown]
# Does the first row of original df equate to the first row of train?

# %%
print(df_resampled.head(1) == train.head(1))
# Out:
#                            quantity  sales_total
# sale_date
# 2013-01-01 00:00:00+00:00      True         True

# %% [markdown]
# Is the last row of train the day before the first row of validate? And the same for validate to test?

# %%
pd.concat([train.tail(1), validate.head(1)])
# Out:
#                            quantity  sales_total
# sale_date
# 2015-07-02 00:00:00+00:00   33134.0    178036.64
# 2015-07-03 00:00:00+00:00   35498.0    190981.55

# %%
pd.concat([validate.tail(1), test.head(1)])
# Out:
#                            quantity  sales_total
# sale_date
# 2016-12-31 00:00:00+00:00   23792.0    128009.31
# 2017-01-01 00:00:00+00:00   23709.0    127262.71

# %% [markdown]
# Is the last row of test the same as the last row of our original dataframe?

# %%
pd.concat([test.tail(1), df_resampled.tail(1)])
# Out:
#                            quantity  sales_total
# sale_date
# 2017-12-31 00:00:00+00:00   26420.0    140905.74
# 2017-12-31 00:00:00+00:00   26420.0    140905.74

# %% [markdown]
# Let's plot our data first, viewing where the data is split into train and test.

# %%
train.columns
# Out:
# Index(['quantity', 'sales_total'], dtype='object')

# %%
for col in train.columns:
    plt.figure(figsize=(14,8))
    plt.plot(train[col])
    plt.plot(validate[col])
    plt.plot(test[col])
    plt.ylabel(col)
    plt.title(col)
    plt.show()

# %% [markdown]
# Before we try out different methods for forecasting sales and number of items sold, let's create a couple of functions that will be helpful in evaluating each of the methods that follow.
#
# `evaluate()` will compute the Mean Squared Error and the Rood Mean Squared Error to evaluate.

# %%
def evaluate(target_var):
    '''
    This function will take the actual values of the target_var from validate, 
    and the predicted values stored in yhat_df, 
    and compute the rmse, rounding to 0 decimal places. 
    it will return the rmse. 
    '''
    rmse = round(sqrt(mean_squared_error(validate[target_var], yhat_df[target_var])), 0)
    return rmse

# %% [markdown]
# `plot_and_eval()` will use the evaluate function and also plot train and test values with the predicted values in order to compare performance.

# %%
def plot_and_eval(target_var):
    '''
    This function takes in the target var name (string), and returns a plot
    of the values of train for that variable, validate, and the predicted values from yhat_df. 
    it will als lable the rmse. 
    '''
    plt.figure(figsize = (12,4))
    plt.plot(train[target_var], label='Train', linewidth=1)
    plt.plot(validate[target_var], label='Validate', linewidth=1)
    plt.plot(yhat_df[target_var])
    plt.title(target_var)
    rmse = evaluate(target_var)
    print(target_var, '-- RMSE: {:.0f}'.format(rmse))
    plt.show()

# %% [markdown]
# Write `append_eval_df(model_type)` to append evaluation metrics for each model type, target variable, and metric type, along with the metric value into our `eval_df` data frame object. Which we will create an empty `eval_df` dataframe object to start.

# %%
# create an empty dataframe
eval_df = pd.DataFrame(columns=['model_type', 'target_var', 'rmse'])
eval_df
# Out:
# Empty DataFrame
# Columns: [model_type, target_var, rmse]
# Index: []

# %%
# function to store the rmse so that we can compare
def append_eval_df(model_type, target_var):
    '''
    this function takes in as arguments the type of model run, and the name of the target variable. 
    It returns the eval_df with the rmse appended to it for that model and target_var. 
    '''
    rmse = evaluate(target_var)
    d = {'model_type': [model_type], 'target_var': [target_var],
        'rmse': [rmse]}
    d = pd.DataFrame(d)
    return eval_df.append(d, ignore_index = True)

# %%
eval_df
# Out:
# Empty DataFrame
# Columns: [model_type, target_var, rmse]
# Index: []

# %% [markdown]
# ## Forecast
#
# Forecasting is another word for predicting time series data.
#
# 1. Last Observed Value: The future will look like the now
# 2. Simple Average: The future will look, on average, like history.
# 3. Moving Average: The future will look, on average, like recent history.
# 4. Holt's Linear Trend
# 5. Previous Cycle
#
#
# ### Last observed value
#
# The simplest method for forecasting is to predict all future values to be the last observed value.
#
# **Make Predictions**
#
# Sales Total

# %%
train['sales_total'][-1:][0]
# Out:
# 178036.64

# %%
# take the last item of sales total and assign to variable
last_sales = train['sales_total'][-1:][0]
last_sales
# Out:
# 178036.64

# %% [markdown]
# Quantity

# %%
# take the last item of quantity and assign to variable
last_quantity = train['quantity'][-1:][0]
last_quantity
# Out:
# 33134.0

# %%
yhat_df = pd.DataFrame(
    {'sales_total': [last_sales],
     'quantity': [last_quantity]},
    index=validate.index)

yhat_df.head()
# Out:
#                            sales_total  quantity
# sale_date
# 2015-07-03 00:00:00+00:00    178036.64   33134.0
# 2015-07-04 00:00:00+00:00    178036.64   33134.0
# 2015-07-05 00:00:00+00:00    178036.64   33134.0
# 2015-07-06 00:00:00+00:00    178036.64   33134.0
# 2015-07-07 00:00:00+00:00    178036.64   33134.0

# %%
yhat_df.describe()
# Out:
#         sales_total  quantity
# count  5.480000e+02     548.0
# mean   1.780366e+05   33134.0
# std    4.952172e-10       0.0
# min    1.780366e+05   33134.0
# 25%    1.780366e+05   33134.0
# 50%    1.780366e+05   33134.0
# 75%    1.780366e+05   33134.0
# max    1.780366e+05   33134.0

# %% [markdown]
# You can see, when peeking into yhat_df, that every predicted value is the same.
#
# **Plot Actual vs. Predicted Values**
#
# Now, let's plot actual and predicted values

# %%
plot_and_eval('sales_total')
# Out:
# sales_total -- RMSE: 42805

# %%
for col in train.columns:
    plot_and_eval(col)
# Out:
# quantity -- RMSE: 7973
# sales_total -- RMSE: 42805

# %% [markdown]
# **Evaluate**
#
# Evaluate using MSE and RMSE, and add evaluation metrics to `eval_df`

# %%
for col in train.columns:
    eval_df = append_eval_df(model_type = 'last_observed_value', 
                             target_var = col)

eval_df
# Out:
#             model_type   target_var     rmse
# 0  last_observed_value     quantity   7973.0
# 1  last_observed_value  sales_total  42805.0

# %% [markdown]
# ### Simple Average
#
# Take the simple average of historical values and use that value to predict future values.
#
# This is a good option for an initial baseline. Every future datapoint (those in 'test') will be assigned the same value, and that value will be the overall mean of the values in train.
#
# **Make Predictions**
#
# Dollars: establishing the value of the prediction we will make

# %%
# compute simple average
avg_sales = round(train['sales_total'].mean(), 2)
avg_sales
# Out:
# 127573.19

# %% [markdown]
# Items: establishing the value of the prediction we will make

# %%
avg_quantity = round(train['quantity'].mean(), 2)
avg_quantity
# Out:
# 23728.25

# %% [markdown]
# Apply predictions to our observations

# %%
def make_predictions(sales=None, quantity=None):
    yhat_df = pd.DataFrame({'sales_total': [sales],
                           'quantity': [quantity]},
                          index=validate.index)
    return yhat_df

# %%
yhat_df = make_predictions(avg_sales, avg_quantity)

# %%
yhat_df.head()
# Out:
#                            sales_total  quantity
# sale_date
# 2015-07-03 00:00:00+00:00    127573.19  23728.25
# 2015-07-04 00:00:00+00:00    127573.19  23728.25
# 2015-07-05 00:00:00+00:00    127573.19  23728.25
# 2015-07-06 00:00:00+00:00    127573.19  23728.25
# 2015-07-07 00:00:00+00:00    127573.19  23728.25

# %%
yhat_df.describe()
# Out:
#         sales_total  quantity
# count  5.480000e+02    548.00
# mean   1.275732e+05  23728.25
# std    9.467387e-10      0.00
# min    1.275732e+05  23728.25
# 25%    1.275732e+05  23728.25
# 50%    1.275732e+05  23728.25
# 75%    1.275732e+05  23728.25
# max    1.275732e+05  23728.25

# %% [markdown]
# **Plot Actual vs. Predicted Values**
#
# Now, let's plot and evaluate the performance of our time series model using **Simple Average**

# %%
for col in train.columns:
    plot_and_eval(col)
# Out:
# quantity -- RMSE: 7360
# sales_total -- RMSE: 39568

# %% [markdown]
# **Evaluate**
#
# Evaluate using MSE and RMSE, and add evaluation metrics to `eval_df`

# %%
for col in train.columns:
    eval_df = append_eval_df(model_type='simple_average', 
                            target_var = col)
eval_df
# Out:
#             model_type   target_var     rmse
# 0  last_observed_value     quantity   7973.0
# 1  last_observed_value  sales_total  42805.0
# 2       simple_average     quantity   7360.0
# 3       simple_average  sales_total  39568.0

# %% [markdown]
# ### Moving Average
#
# In this example, we will use a 30-day moving average to forecast. In other words, the average over the last 30-days will be used as the forecasted value.

# %%
# demonstrate that the mean of the first 30 days 
# is equal to rolling(30) on day 30

print(train['sales_total'].rolling(30).mean())
# Out:
# sale_date
# 2013-01-01 00:00:00+00:00              NaN
# 2013-01-02 00:00:00+00:00              NaN
# 2013-01-03 00:00:00+00:00              NaN
# 2013-01-04 00:00:00+00:00              NaN
# 2013-01-05 00:00:00+00:00              NaN
#                                  ...
# 2015-06-28 00:00:00+00:00    170365.098000
# 2015-06-29 00:00:00+00:00    168925.788333
# 2015-06-30 00:00:00+00:00    167925.392000
# 2015-07-01 00:00:00+00:00    168957.912000
# 2015-07-02 00:00:00+00:00    169649.376333
# Freq: D, Name: sales_total, Length: 913, dtype: float64

# %% [markdown]
# **Make Predictions**

# %%
period=30
train['sales_total'].rolling(period).mean()[-1]
# Out:
# 169649.37633333338

# %%
period = 30 

# take 30 day rolling average, then take the last element and that will the one that propogates 
# forward as our prediction. 
rolling_sales = round(train['sales_total'].rolling(period).mean()[-1], 2)
rolling_quantity = round(train['quantity'].rolling(period).mean()[-1], 2)
print(rolling_sales, rolling_quantity)
# Out:
# 169649.38 31561.9

# %%
yhat_df = make_predictions(rolling_sales, rolling_quantity)
yhat_df.head()
# Out:
#                            sales_total  quantity
# sale_date
# 2015-07-03 00:00:00+00:00    169649.38   31561.9
# 2015-07-04 00:00:00+00:00    169649.38   31561.9
# 2015-07-05 00:00:00+00:00    169649.38   31561.9
# 2015-07-06 00:00:00+00:00    169649.38   31561.9
# 2015-07-07 00:00:00+00:00    169649.38   31561.9

# %% [markdown]
# **Plot Actual vs. Predicted Values**
#
# Now, let's plot and evaluate the performance of our time series model using **Moving Average**

# %%
for col in train.columns:
    plot_and_eval(col)
# Out:
# quantity -- RMSE: 7048
# sales_total -- RMSE: 37882

# %% [markdown]
# **Evaluate**
#
# Evaluate using MSE and RMSE, and add evaluation metrics to `eval_df`

# %%
for col in train.columns:
    eval_df = append_eval_df(model_type = '30d_moving_avg', 
                            target_var = col)

eval_df
# Out:
#             model_type   target_var     rmse
# 0  last_observed_value     quantity   7973.0
# 1  last_observed_value  sales_total  42805.0
# 2       simple_average     quantity   7360.0
# 3       simple_average  sales_total  39568.0
# 4       30d_moving_avg     quantity   7048.0
# 5       30d_moving_avg  sales_total  37882.0

# %% [markdown]
# Let's try out several other values for periods:

# %%
periods = [4, 12, 26, 52, 104]

for p in periods: 
    rolling_sales = round(train['sales_total'].rolling(p).mean()[-1], 2)
    rolling_quantity = round(train['quantity'].rolling(p).mean()[-1], 2)
    yhat_df = make_predictions(rolling_sales, rolling_quantity)
    model_type = str(p) + '_day_moving_avg'
    for col in train.columns:
        eval_df = append_eval_df(model_type = model_type,
                                target_var = col)

# %%
eval_df
# Out:
#              model_type   target_var     rmse
# 0   last_observed_value     quantity   7973.0
# 1   last_observed_value  sales_total  42805.0
# 2        simple_average     quantity   7360.0
# 3        simple_average  sales_total  39568.0
# 4        30d_moving_avg     quantity   7048.0
# 5        30d_moving_avg  sales_total  37882.0
# 6      4_day_moving_avg     quantity   6258.0
# 7      4_day_moving_avg  sales_total  33696.0
# 8     12_day_moving_avg     quantity   6929.0
# 9     12_day_moving_avg  sales_total  37297.0
# 10    26_day_moving_avg     quantity   6991.0
# 11    26_day_moving_avg  sales_total  37576.0
# 12    52_day_moving_avg     quantity   6666.0
# 13    52_day_moving_avg  sales_total  35876.0
# 14   104_day_moving_avg     quantity   6130.0
# 15   104_day_moving_avg  sales_total  32959.0

# %% [markdown]
# Which is best so far?

# %%
min_items_rmse = eval_df[eval_df.target_var == 'quantity']['rmse'].min()

# %%
min_items_rmse
# Out:
# 6130.0

# %%
eval_df[eval_df.rmse == min_items_rmse]
# Out:
#             model_type target_var    rmse
# 14  104_day_moving_avg   quantity  6130.0

# %%
min_dollars_rmse = eval_df[eval_df.target_var == 'sales_total']['rmse'].min()

eval_df[eval_df.rmse == min_dollars_rmse]
# Out:
#             model_type   target_var     rmse
# 15  104_day_moving_avg  sales_total  32959.0

# %% [markdown]
# ### Holt's Linear Trend
#
#
# Exponential smoothing applied to both the average and the trend (slope).
#
# - $\alpha$ / smoothing_level: smoothing parameter for mean. Values closer to 1 will have less of a smoothing effect and will give greater weight to recent values.
# - $\beta$ / smoothing_slope: smoothing parameter for the slope. Values closer to 1 will give greater weight to recent slope/values.
#
#
#
# **Seasonal Decomposition**
#
#
# First, let's take a look at the seasonal decomposition for each target.

# %%
import statsmodels.api as sm

# %%
print(col, '\n')
sm.tsa.seasonal_decompose(train[col].resample('W').mean()).plot()
plt.show()
# Out:
# sales_total

# %%
for col in train.columns:
    print(col,'\n')
    sm.tsa.seasonal_decompose(train[col].resample('W').mean()).plot()
# Out:
# quantity
#
# sales_total

# %% [markdown]
# #### Basic Holt's Linear Trend
#
# **Make Predictions**
#
# Now, like we would when using sklearn, we will create the Holt object, fit the model, and make predictions.
#
# Holt:
#
# - exponential = True/False (exponential vs. linear growth, additive vs. multiplicative)
# - damped $\phi$ = True/False: with Holt, forecasts will increase or decrease indefinitely into the future.  To avoid this, use the Damped trend method which has a damping parameter 0< ϕ <1.
#
#
# fit:
#
# - smoothing_level ($\alpha$): value between (0,1)
# - smoothing_slope ($\beta$): value between (0,1)
# - optimized: use the auto-optimization that allow statsmodels to automatically find an optimized value for us.

# %%
train.columns
# Out:
# Index(['quantity', 'sales_total'], dtype='object')

# %%
col = 'sales_total' 
# create our Holt's Object
model = Holt(train[col], exponential=False, damped=True)

# %%
# fit the holt's object
model = model.fit(optimized=True)
# Out:
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/holtwinters/model.py:920: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(

# %%
yhat_items = model.predict(start = validate.index[0],
                              end = validate.index[-1])

# %%
validate.shape
# Out:
# (548, 2)

# %%
yhat_items
# Out:
# 2015-07-03 00:00:00+00:00    171117.753291
# 2015-07-04 00:00:00+00:00    171264.819256
# 2015-07-05 00:00:00+00:00    171410.399197
# 2015-07-06 00:00:00+00:00    171554.508129
# 2015-07-07 00:00:00+00:00    171697.160916
#                                  ...
# 2016-12-27 00:00:00+00:00    185613.674887
# 2016-12-28 00:00:00+00:00    185614.267179
# 2016-12-29 00:00:00+00:00    185614.853485
# 2016-12-30 00:00:00+00:00    185615.433867
# 2016-12-31 00:00:00+00:00    185616.008384
# Freq: D, Length: 548, dtype: float64

# %%
# doing this in a loop for each column
for col in train.columns:
    model = Holt(train[col], exponential=False, damped=True)
    model = model.fit(optimized=True)
    yhat_items = model.predict(start = validate.index[0],
                              end = validate.index[-1])
    yhat_df[col] = round(yhat_items, 2)
# Out:
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/holtwinters/model.py:920: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/holtwinters/model.py:920: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(

# %%
yhat_df
# Out:
#                            sales_total  quantity
# sale_date
# 2015-07-03 00:00:00+00:00    171117.75  31831.17
# 2015-07-04 00:00:00+00:00    171264.82  31858.88
# 2015-07-05 00:00:00+00:00    171410.40  31886.32
# 2015-07-06 00:00:00+00:00    171554.51  31913.48
# 2015-07-07 00:00:00+00:00    171697.16  31940.36
# ...                                ...       ...
# 2016-12-27 00:00:00+00:00    185613.67  34590.34
# 2016-12-28 00:00:00+00:00    185614.27  34590.46
# 2016-12-29 00:00:00+00:00    185614.85  34590.57
# 2016-12-30 00:00:00+00:00    185615.43  34590.69
# 2016-12-31 00:00:00+00:00    185616.01  34590.80
#
# [548 rows x 2 columns]

# %% [markdown]
# To practice the code before putting in a loop, as above...

# %%
col = 'sales_total'
# create the Holt object 
model = Holt(train[col], exponential=False, damped=True)
# fit the model 
model = model.fit(optimized=True)
# make predictions for each date in validate 
yhat_items = model.predict(start = validate.index[0],
                           end = validate.index[-1])
# add predictions to yhat_df
yhat_df[col] = round(yhat_items, 2)
# Out:
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/holtwinters/model.py:920: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(

# %%
yhat_df
# Out:
#                            sales_total  quantity
# sale_date
# 2015-07-03 00:00:00+00:00    171117.75  31831.17
# 2015-07-04 00:00:00+00:00    171264.82  31858.88
# 2015-07-05 00:00:00+00:00    171410.40  31886.32
# 2015-07-06 00:00:00+00:00    171554.51  31913.48
# 2015-07-07 00:00:00+00:00    171697.16  31940.36
# ...                                ...       ...
# 2016-12-27 00:00:00+00:00    185613.67  34590.34
# 2016-12-28 00:00:00+00:00    185614.27  34590.46
# 2016-12-29 00:00:00+00:00    185614.85  34590.57
# 2016-12-30 00:00:00+00:00    185615.43  34590.69
# 2016-12-31 00:00:00+00:00    185616.01  34590.80
#
# [548 rows x 2 columns]

# %%
validate
# Out:
#                            quantity  sales_total
# sale_date
# 2015-07-03 00:00:00+00:00   35498.0    190981.55
# 2015-07-04 00:00:00+00:00   37776.0    203696.39
# 2015-07-05 00:00:00+00:00   39740.0    214040.37
# 2015-07-06 00:00:00+00:00   26519.0    142584.15
# 2015-07-07 00:00:00+00:00   30916.0    167146.03
# ...                             ...          ...
# 2016-12-27 00:00:00+00:00   19341.0    103657.89
# 2016-12-28 00:00:00+00:00   19560.0    105313.94
# 2016-12-29 00:00:00+00:00   21111.0    113221.85
# 2016-12-30 00:00:00+00:00   22296.0    120033.64
# 2016-12-31 00:00:00+00:00   23792.0    128009.31
#
# [548 rows x 2 columns]

# %%
yhat_items
# Out:
# 2015-07-03 00:00:00+00:00    171117.753291
# 2015-07-04 00:00:00+00:00    171264.819256
# 2015-07-05 00:00:00+00:00    171410.399197
# 2015-07-06 00:00:00+00:00    171554.508129
# 2015-07-07 00:00:00+00:00    171697.160916
#                                  ...
# 2016-12-27 00:00:00+00:00    185613.674887
# 2016-12-28 00:00:00+00:00    185614.267179
# 2016-12-29 00:00:00+00:00    185614.853485
# 2016-12-30 00:00:00+00:00    185615.433867
# 2016-12-31 00:00:00+00:00    185616.008384
# Freq: D, Length: 548, dtype: float64

# %%
yhat_df
# Out:
#                            sales_total  quantity
# sale_date
# 2015-07-03 00:00:00+00:00    171117.75  31831.17
# 2015-07-04 00:00:00+00:00    171264.82  31858.88
# 2015-07-05 00:00:00+00:00    171410.40  31886.32
# 2015-07-06 00:00:00+00:00    171554.51  31913.48
# 2015-07-07 00:00:00+00:00    171697.16  31940.36
# ...                                ...       ...
# 2016-12-27 00:00:00+00:00    185613.67  34590.34
# 2016-12-28 00:00:00+00:00    185614.27  34590.46
# 2016-12-29 00:00:00+00:00    185614.85  34590.57
# 2016-12-30 00:00:00+00:00    185615.43  34590.69
# 2016-12-31 00:00:00+00:00    185616.01  34590.80
#
# [548 rows x 2 columns]

# %% [markdown]
# **Plot Actual vs. Predicted Values**

# %%
for col in train.columns:
    plot_and_eval(target_var = col)
# Out:
# quantity -- RMSE: 8692
# sales_total -- RMSE: 46542

# %% [markdown]
# **Evaluate**

# %%
for col in train.columns:
    eval_df = append_eval_df(model_type = 'holts_optimized', 
                            target_var = col)

# %%
eval_df.sort_values(by='rmse')
# Out:
#              model_type   target_var     rmse
# 14   104_day_moving_avg     quantity   6130.0
# 6      4_day_moving_avg     quantity   6258.0
# 12    52_day_moving_avg     quantity   6666.0
# 8     12_day_moving_avg     quantity   6929.0
# 10    26_day_moving_avg     quantity   6991.0
# 4        30d_moving_avg     quantity   7048.0
# 2        simple_average     quantity   7360.0
# 0   last_observed_value     quantity   7973.0
# 16      holts_optimized     quantity   8692.0
# 15   104_day_moving_avg  sales_total  32959.0
# 7      4_day_moving_avg  sales_total  33696.0
# 13    52_day_moving_avg  sales_total  35876.0
# 9     12_day_moving_avg  sales_total  37297.0
# 11    26_day_moving_avg  sales_total  37576.0
# 5        30d_moving_avg  sales_total  37882.0
# 3        simple_average  sales_total  39568.0
# 1   last_observed_value  sales_total  42805.0
# 17      holts_optimized  sales_total  46542.0

# %% [markdown]
# ### Predict Based on Previous Cycle

# %% [markdown]
# Take all the 2016 data points, compute the daily delta, year-over-year, average that delta over all the days, and adding that average to the previous year's value on a day will give you the forecast for that day.
#
# If a primary cycle is weekly, then you may want to do this on a week-over-week cadence.
#
# In the below example:
# 1. Compute the 365 average year over year differences from 2013 through 2015
# 2. Add that average delta to the values during 2015.
# 3. Set the index in your yhat dataframe to represent the dates those predictions are make for.
#
# Let's get started....
#
# **Re-split data**

# %%
train = df_resampled[:'2015']
validate = df_resampled['2016']
test = df_resampled['2017']

print(train.shape)
print(validate.shape)
print(test.shape)

train.head()
train.tail()
# Out:
# (1095, 2)
# (366, 2)
# (365, 2)
#                            quantity  sales_total
# sale_date
# 2015-12-27 00:00:00+00:00   23268.0    125125.86
# 2015-12-28 00:00:00+00:00   15569.0     84297.45
# 2015-12-29 00:00:00+00:00   18403.0     98602.75
# 2015-12-30 00:00:00+00:00   18191.0     97773.10
# 2015-12-31 00:00:00+00:00   19377.0    103969.42

# %% [markdown]
# **Make Predictions**

# %%
# finding the year-over-year difference for each day from 2013 to 2015
# taking the mean, and then adding that value to the daily 2015 values. 

# find yoy diff. from 2013-2014 and 2014-2015, take the mean, and add to each value in 2015. 
yhat_df = train['2015'] + train.diff(365).mean()

# %%
train.diff(365).mean()
# Out:
# quantity        2185.813699
# sales_total    11751.250493
# dtype: float64

# %% [markdown]
# Back to predictions

# %%
train.loc['2015'].head()
# Out:
#                            quantity  sales_total
# sale_date
# 2015-01-01 00:00:00+00:00   17226.0     92586.37
# 2015-01-02 00:00:00+00:00   18719.0    101119.52
# 2015-01-03 00:00:00+00:00   19798.0    106494.05
# 2015-01-04 00:00:00+00:00   21101.0    113745.51
# 2015-01-05 00:00:00+00:00   14235.0     76800.69

# %%
yhat_df.head()
# Out:
#                                quantity    sales_total
# sale_date
# 2015-01-01 00:00:00+00:00  19411.813699  104337.620493
# 2015-01-02 00:00:00+00:00  20904.813699  112870.770493
# 2015-01-03 00:00:00+00:00  21983.813699  118245.300493
# 2015-01-04 00:00:00+00:00  23286.813699  125496.760493
# 2015-01-05 00:00:00+00:00  16420.813699   88551.940493

# %%
# let's peek into the prediction we will make for 1/1/2016
# by comparing the predicted value 
# (2015 value + year-over-year average difference)
# to the actual 1/1/2016 value
pd.concat([yhat_df.head(1), validate.head(1)])
# Out:
#                                quantity    sales_total
# sale_date
# 2015-01-01 00:00:00+00:00  19411.813699  104337.620493
# 2016-01-01 00:00:00+00:00  20158.000000  107875.260000

# %%
# set yhat_df to index of validate
yhat_df.index = validate.index
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/bk/zhdff0zs3yz8v31x8wdnftxm0000gn/T/ipykernel_37753/4219291392.py in <module>
#       1 # set yhat_df to index of validate
# ----> 2 yhat_df.index = validate.index
#
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5498         try:
#    5499             object.__getattribute__(self, name)
# -> 5500             return object.__setattr__(self, name, value)
#    5501         except AttributeError:
#    5502             pass
#
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     764     def _set_axis(self, axis: int, labels: Index) -> None:
#     765         labels = ensure_index(labels)
# --> 766         self._mgr.set_axis(axis, labels)
#     767         self._clear_item_cache()
#     768
#
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py in set_axis(self, axis, new_labels)
#     214     def set_axis(self, axis: int, new_labels: Index) -> None:
#     215         # Caller is responsible for ensuring we have an Index object.
# --> 216         self._validate_set_axis(axis, new_labels)
#     217         self.axes[axis] = new_labels
#     218
#
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/core/internals/base.py in _validate_set_axis(self, axis, new_labels)
#      55
#      56         elif new_len != old_len:
# ---> 57             raise ValueError(
#      58                 f"Length mismatch: Expected axis has {old_len} elements, new "
#      59                 f"values have {new_len} elements"
#
# ValueError: Length mismatch: Expected axis has 365 elements, new values have 366 elements

# %%
yhat_df.shape

# %%
validate.shape # A leap year!

# %%
validate = validate[validate.index != '2016-02-29']

# %%
# set yhat_df to index of validate
yhat_df.index = validate.index

# %%
yhat_df.describe()

# %%
yhat_df.head()

# %%
yhat_df.shape

# %% [markdown]
# **Plot and Evaluate**

# %%
for col in train.columns:
    plot_and_eval(target_var = col)
    eval_df = append_eval_df(model_type = "previous_year", 
                            target_var = col)

# %% [markdown]
# ## Conclusion
#
# Which model did the best?

# %%
sales_total_min_rmse = eval_df.groupby('target_var')['rmse'].min()[0]

quantity_min_rmse = eval_df.groupby('target_var')['rmse'].min()[1]

# find which model that is
eval_df[((eval_df.rmse == sales_total_min_rmse) | 
         (eval_df.rmse == quantity_min_rmse))]

# %% [markdown]
# Let's test it out on our out-of-sample data
#
# We will be using train + validate to predict test.

# %%
yhat_df = validate + train.diff(365).mean()
yhat_df.index = test.index

# %%
yhat_df

# %%
def final_plot(target_var):
    plt.figure(figsize=(12,4))
    plt.plot(train[target_var], label='train')
    plt.plot(validate[target_var], label='validate')
    plt.plot(test[target_var], label='test')
    plt.plot(yhat_df[target_var], alpha=.5)
    plt.title(target_var)
    plt.show()

# %%
rmse_sales_total = sqrt(mean_squared_error(test['sales_total'], 
                                       yhat_df['sales_total']))

rmse_quantity = sqrt(mean_squared_error(test['quantity'], 
                                       yhat_df['quantity']))

# %%
print('rmse-sales total: ', rmse_sales_total)
print('rmse-quantity: ', rmse_quantity)

# %%
for col in train.columns:
    final_plot(col)

# %%
# to predict 2018

yhat_df = test + train.diff(365).mean()

yhat_df.index = test.index + pd.Timedelta('1Y')

# %%
yhat_df.head()

# %%
def final_plot(target_var):
    plt.figure(figsize=(12,4))
    plt.plot(train[target_var], label='train')
    plt.plot(validate[target_var], label='validate')
    plt.plot(test[target_var], label='test')
    plt.plot(yhat_df[target_var], alpha=.5, label='forecast')
    plt.title(target_var)
    plt.legend()
    plt.show()

# %%
for col in train.columns:
    final_plot(col)

# %% [markdown]
# ## Exercises
#
# The end result of this exercise should be a Jupyter notebook named `model`.
#
# Using [saas.csv](https://ds.codeup.com/saas.csv) or log data from API usage or store_item_sales
#
# 1. Split data (train/test) and resample by any period, except daily, and aggregate using the sum.
# 2. Forecast, plot and evaluate using each of the 4 parametric based methods we discussed:
#     - Simple Average
#     - Moving Average
#     - Holt's Linear Trend Model
#     - Based on previous year/month/etc., this is up to you.
#
# Optional: Using store item demand
#
# 1. Predict 2018 total **monthly** sales for a single store and/or item by creating a model using prophet.
# 2. Return a dataframe with the month, store_id, y-hat, and the confidence intervals (y-hat lower, y-hat upper).
# 3. Plot the 2018 monthly sales predictions.
